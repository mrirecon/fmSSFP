# %% [markdown]
# # fmSSFP reconstruction using BART

# %%
bart version
# Out:
# v0.4.04-107-g1fc89d2

# %%
./fmSSFPsubsp.sh -lreco0.log -g0 brain-singleslice-turnbased.cfl reco0
# Out:
# BART-based fmSSFP reco v0.2
#
# Turn-based trajectory

# %%
bart toimg reco0 reco0.png
cat reco0.png | display
# Out:
# Writing 1 image(s)...done.

# %%
./fmSSFPsubsp.sh -lreco1.log -g1 brain-singleslice-goldenangle.cfl reco1
# Out:
# BART-based fmSSFP reco v0.2
#
# Golden Angle trajectory

# %%
bart toimg reco1 reco1.png
cat reco1.png | display
# Out:
# Writing 1 image(s)...done.
